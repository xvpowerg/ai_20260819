# %%
class Animal:
    def __init__(self,name,age):
        #作業
        #name 私有化 不可空白 長度必須大於1
        self.__name = name
        #__age 是私有屬性
        self.__age = age
    def setAge(self,age):
        if age < 0 or age > 200:
            raise OverflowError(f"年齡不合理:{age}")
        self.__age = age
    def getAge(self):    
        return self.__age
    def setName(self,name): 
        if  len(name) < 2:
            raise ValueError(f"名稱不合理:{name}")
        self.__name = name
    def getName(self):    
        return self.__name
    def printInfo(self):
        print("Name:",self.__name,"Age:",self.__age)    
a1 = Animal("Dog",10)       
a1.printInfo()
a1.setAge(10)
a1.setName("Momey")
a1.printInfo()    
a1.setAge(-100) 
a1.printInfo()
# Out:
# Name: Dog Age: 10
# Name: Momey Age: 10
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[22], line 27
#      23 a1.printInfo()
#      24 a1.setAge(10)
#      25 a1.setName("Momey")
#      26 a1.printInfo()
# ---> 27 a1.setAge(-100)
#      28 a1.printInfo()
#
# Cell In[22], line 10, in Animal.setAge(self, age)
#       8     def setAge(self,age):
#       9         if age < 0 or age > 200:
# ---> 10             raise OverflowError(f"年齡不合理:{age}")
#      11         self.__age = age
#
# OverflowError: 年齡不合理:-100

# %%
import modu  
ob1 = modu.Test1()
modu.func1()
# Out:
# Create
# func1

# %%
import happy.my_mod
happy.my_mod.happy_python()
# Out:
# Happy Python

# %%
import happy.io.my_mod
happy.io.my_mod.happy_python()
# Out:
# IO Happy Python

# %%
import happy.my_mod as mymod
mymod.happy_python()
# Out:
# Happy Python

# %%
from happy.io.my_mod import happy_python
happy_python()
happy_python()
# Out:
# IO Happy Python
# IO Happy Python

# %% [markdown]
# ## 檔案存取
#
# file object = open(file_name [, access_mode])
#
# UTF8 編碼資料還請加入另一個參數才可避免亂碼：encoding=‘utf-8'
# file object = open(file_name [, access_mode])
#
# 參數說明
#
# file_name：file_name 參數是一個字串資料，代表包含要連結的文件名稱。
#
# access_mode：access_mode 確定文件必須打開的模式，包括讀取、寫入、附加等等。稍後會列完整列表。這是可選參數，默認文件訪問模式為讀取(r)。
#
# |模式	|可做操作|若檔案不存在|是否覆蓋|
# |----|--------|-----------|-------|
# |r	|只能讀|報錯	|-|
# |r+	|可讀可寫|報錯|是|
# |w	|只能寫|建立|是|
# |w+ |可讀可寫|建立|是|
# |a　|只能寫|建立|否，追加寫|
# |a+	|可讀可寫|建立|否，追加寫|

# %%
text = """python與中文AAA
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。
"""
file = open("data.txt","w",encoding="utf-8")
file.write(text)
file.close()

# %%
f = open("data.txt",'r',encoding="UTF-8")
content = f.read()
print(content)
f.close()
# Out:
# python與中文AAA
# 1. 我們來試試看中文儲存能力。
# 2. 許這個字會有編碼衝突風險。
# 3. 犇這個字必須是utf8編碼才有。

# %%
import csv
f = open("example1.csv","r")
for row in csv.reader(f):
    if float(row[5]) > 100:
        print(row[0],row[1],row[2])
f.close()
# Out:
#  104/01/03 2,640,781,030 64,138,886,194
#  104/01/17 3,720,277,205 101,133,309,290
#  104/01/30 4,540,373,544 143,900,658,474
#  104/01/31 5,486,734,180 162,361,181,834

# %%
import csv
f = open("example.csv","r",encoding="utf-8")
for row  in csv.DictReader(f):
    print(row["漲跌點數"],row["成交筆數"])

f.close()
# Out:
# -119.87 497,889
# 101.17 623,192
# 29.59 728,417
# 47.89 737,780
# -10.35 823,810
# -27.47 634,137
# 85.83 869,327
# 9.34 802,539
# -1.63 731,328
# -5.04 819,762
# -77.92 719,725
# 117.46 899,597
# 12.61 1,020,420
# 173.72 1,113,727
# 109.67 1,283,951

# %%
import os
print(os.getcwd())
# Out:
# c:\python_code\ai_20260819\ch6

# %%
import os
class TestFile:
    def openFile(self,filePath):
        self.handle = open(filePath,"w")
        self.handle.close()#沒關閉會出錯
t =   TestFile()
t.openFile("test.txt")
os.remove("test.txt")
print("Success")
# Out:
# Success

# %%
import os
class TestFile:
    def openFile(self,filePath):
        with open(filePath,"w") as f:#當縮排內的功能運行完畢f就會自動關閉
            f.write("Hello World")
                    
t =  TestFile()
t.openFile("test.txt")
os.remove("test.txt")
print("Success")
# Out:
# Success

# %% [markdown]
# ## Numpy
# + 可做到的功能
#   + 快速的多維陣列操作。
#   + 可靠的科學功能函數庫。
#   + 可協助繪圖工具進行繪圖。
# + NumPy 是幾乎每個科學 Python 應用程序或模組的核心，它提供了以向量化形式的快速 N-d 陣列類型可供操作。

# %%
import numpy as np
a = [1,2,3,5,7,9]
b = [3,5,3,6,7,9]
print(type(a))
np1 = np.array(a)
np2 = np.array(b)
print(type(np1))
c = a + b
print(c)
np3 = np1 + np2
print(np3)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# [1, 2, 3, 5, 7, 9, 3, 5, 3, 6, 7, 9]
# [ 4  7  6 11 14 18]

# %% [markdown]
# ## 作業 example.csv 漲跌點數大於9.34的幫我輸出 他的漲跌點數

# %%
import numpy as np 
a = [1,2,3,5,7,9]
b = [3,5,3,6,7,9]
print(type(a))
c = a + b
print(c)
np3 = np1 + np2
print(np3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 a = [1,2,3,5,7,9]
#       3 b = [3,5,3,6,7,9]
# ----> 4 print(type(np1))
#       5 c = a + b
#       6 print(c)
#       7 np3 = np1 + np2
#
# NameError: name 'np1' is not defined
