# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0,20,1)
s = np.linspace(0,10,20)
plt.subplot(1,2,1)
plt.plot(t,s)
plt.subplot(1,2,2)
plt.plot(t,s,"r-")
plt.show()

# %% [markdown]
# ## Bar

# %%
import matplotlib.pyplot as plt
import numpy as np
city = ['Delhi', 'Beijing', 'Washington', 'Tokyo', 'Moscow']
Happiness_Index = [60, 40, 70, 65, 85]
pos = np.arange(len(city))
plt.bar(pos,Happiness_Index,color="blue")
plt.xticks(pos,city)
plt.show()

# %% [markdown]
# ## 散佈圖 Scatter

# %%
import matplotlib.pyplot as plt
import numpy as np
h=np.array([159,169,174,165,163,155,180,190])
w=np.array([55,45,70,60,65,45,72,50])
plt.scatter(h,w)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
h=np.array([159,169,174,165,163,155,180,190])
w=np.array([55,45,70,60,65,45,72,50])
plt.scatter(h,w)
plt.xlabel("h")
plt.ylabel("w")
for temp1 in zip(h,w):
    #print(temp1)
    plt.text(temp1[0],temp1[1],f"({temp1[0]},{temp1[1]})")
    #print(temp1[0],temp1[1])
plt.grid()
plt.show()

# %% [markdown]
# ### Hist 直方圖

# %%
import  numpy as np
import  matplotlib.pyplot as plt
values = [82, 76, 24, 40, 67, 62, 75, 78, 71, 32, 98, 89, 78, 67, 72, 82, 87, 66, 56, 52]
x1  = np.arange(len(values))
plt.bar(x1,values)
plt.show()

values = [82, 76, 24, 40, 67, 62, 75, 78, 71, 32, 98, 89, 78, 67, 72, 82, 87, 66, 56, 52]
plt.hist(values,bins = 5,edgecolor="black",linewidth=1)
plt.show()

# %% [markdown]
# ## 圓餅

# %%
import matplotlib.pyplot as plt
import numpy as np
values=[60,80,90,55,10,30]
labels=['US','UK','India','Germany','Australia','South Korea']
explode=(0.1,0,0.1,0,0,0)
plt.show()
plt.pie(values,labels=labels)
plt.show()
plt.pie(values,labels=labels,explode=explode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
values=[60,80,90,55,10,30]
labels=['US','UK','India','Germany','Australia','South Korea']
newLables = []
for temp in zip(values,labels):
    msg = f"{temp[0]}:{temp[1]}"
    print(msg)
    newLables.append(msg)
plt.pie(values,labels=newLables)    
plt.show()
# Out:
# 60:US
# 80:UK
# 90:India
# 55:Germany
# 10:Australia
# 30:South Korea

# %%
import matplotlib.pyplot as plt
import numpy as np
values=[60,80,90,55,10,30]
labels=['US','UK','India','Germany','Australia','South Korea']
newLables = []
for temp in zip(values,labels):
    msg = f"{temp[0]}:{temp[1]}"
    print(msg)
    newLables.append(msg)
plt.pie(values,labels=newLables)
plt.show()
# Out:
# 60:US
# 80:UK
# 90:India
# 55:Germany
# 10:Australia
# 30:South Korea

# %% [markdown]
# ## 箱型圖

# %%
import matplotlib.pyplot as plt
value1 = [82, 76, 24, 40, 67, 62, 75, 78, 71, 32, 98, 89, 78, 67, 72, 82, 87, 66, 56, 52]
plt.boxplot(value1)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 建立資料
df = pd.DataFrame({
    "Class": ["A"] * 5 + ["B"] * 5 + ["C"] * 5,
    "Score": [
        60, 70, 75, 80, 90,      # A班
        55, 65, 70, 72, 85,      # B班
        70, 75, 80, 88, 95       # C班
    ]
})

# 畫多組箱型圖
sns.boxplot(
    data=df,
    x="Class",
    y="Score"
)

plt.show()

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np
fruits  = ['蘋果','橘子','梨子','櫻桃']
quantities = [15,33,45,55]
s1 = pd.Series(quantities)
s2 = pd.Series(quantities,index = fruits)

print(s1)
print("================")
print(s2)
print("================")
print(s1[1])
print("================")
print(s2["梨子"])
# Out:
# 0    15
# 1    33
# 2    45
# 3    55
# dtype: int64
# ================
# 蘋果    15
# 橘子    33
# 梨子    45
# 櫻桃    55
# dtype: int64
# ================
# 33
# ================
# 45

# %%
import pandas as pd
data = {"Name":['Tom','Jack','Steve',"Ricky"],
       "Age":[28,34,29,42]}
print(type(data))
df = pd.DataFrame(data)
print(df)
df2 = pd.DataFrame(data,index=["man1","man2","man3","man4"])
print(df2)
print("=======")
print(type(df["Name"]))
print(df["Name"])
# Out:
# <class 'dict'>
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42
#        Name  Age
# man1    Tom   28
# man2   Jack   34
# man3  Steve   29
# man4  Ricky   42
# =======
# <class 'pandas.Series'>
# 0      Tom
# 1     Jack
# 2    Steve
# 3    Ricky
# Name: Name, dtype: str

# %%
import  pandas as pd
import  numpy as np
array1=np.array([[10,30],[20,40]])
df = pd.DataFrame(array1)
print(df)
df.columns = ["col1","col2"]
print(df)
df.index = ["row1","row2"]
print(df)
# Out:
#     0   1
# 0  10  30
# 1  20  40
#    col1  col2
# 0    10    30
# 1    20    40
#       col1  col2
# row1    10    30
# row2    20    40

# %%
import  pandas as pd
import  numpy as np
array1=np.array([[10,30],[20,40]])
df2 = pd.DataFrame(columns=["col1","col2"],index = ["row1","row2"])
print(df2)
df2.loc["row1"] = array1[0]
df2.loc["row2"] = array1[1]
print(df2)
# Out:
#      col1 col2
# row1  NaN  NaN
# row2  NaN  NaN
#      col1 col2
# row1   10   30
# row2   20   40

# %% [markdown]
# ## 合併

# %%
import pandas as pd
d = {'one':pd.Series([1,2,3],index=['a','b','c']),
     'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df1 = pd.DataFrame(d)
df1["three"] = [10,11,12,13]
print(df1)
df2 = pd.DataFrame([[20, 21, 22],
                    [23, 24, 25],
                    [26,27, 28]], columns=['one', 'two', 'three'],
                    index=['a','b','c'])
print(df2)
df3 = pd.concat([df1,df2],ignore_index=True)#垂直 沿軸0方向合併
df3.index = ['a','b','c',"d","e","f","g"]
print(df3)
df4 = pd.concat([df1,df2],ignore_index=True,axis=1)#水平合併 沿軸1方向合併
print(df4)
# Out:
#    one  two  three
# a  1.0    1     10
# b  2.0    2     11
# c  3.0    3     12
# d  NaN    4     13
#    one  two  three
# a   20   21     22
# b   23   24     25
# c   26   27     28
#     one  two  three
# a   1.0    1     10
# b   2.0    2     11
# c   3.0    3     12
# d   NaN    4     13
# e  20.0   21     22
# f  23.0   24     25
# g  26.0   27     28
#      0  1   2     3     4     5
# a  1.0  1  10  20.0  21.0  22.0
# b  2.0  2  11  23.0  24.0  25.0
# c  3.0  3  12  26.0  27.0  28.0
# d  NaN  4  13   NaN   NaN   NaN

# %% [markdown]
# ## 刪除

# %%
import pandas as pd
d = {'one':pd.Series([1,2,3],index=['a','b','c']),
     'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df1 = pd.DataFrame(d)
df1["three"] = [10,11,12,13]
print(df1)
df1.drop("one",axis=1,inplace=True)#我在軸1找one欄位刪除他
print(df1)
df1.drop("c",axis=0,inplace=True)#我在軸0找one欄位刪除他
print(df1)
# Out:
#    one  two  three
# a  1.0    1     10
# b  2.0    2     11
# c  3.0    3     12
# d  NaN    4     13
#    two  three
# a    1     10
# b    2     11
# c    3     12
# d    4     13
#    two  three
# a    1     10
# b    2     11
# d    4     13

# %% [markdown]
# ## Pandas 讀取CSV

# %%
import pandas as pd
df1 = pd.read_csv("./ex1.csv")
print(df1)
df2 = pd.read_csv("./ex1.csv",names=["A","B","C","D","E"])
print(df2)
df3 = pd.read_csv("./ex1.csv",index_col="c")
print(df3)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    good
#    A   B   C   D        E
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12     good
#     a   b   d message
# c
# 3   1   2   4   hello
# 7   5   6   8   world
# 11  9  10  12    good

# %%
import  pandas as pd
import  numpy as np
#龘 (音踏)  犇(音奔)
data={
    'Name':['犇','中文','龘','Ricky'],
    'Age':[28,34,29,42]
}
print(data)
df=pd.DataFrame(data)
writer = pd.ExcelWriter("df.xlsx")
df.to_excel(writer,sheet_name="Sheet3")
df1=pd.DataFrame(np.arange(9).reshape(3,3),
                 index=['a','c','d'],
                 columns=['One','Two','Three'])
df1.to_excel(writer,sheet_name="哈嘍")
writer.close()
# Out:
# {'Name': ['犇', '中文', '龘', 'Ricky'], 'Age': [28, 34, 29, 42]}

# %%
import  pandas as pd
df = pd.read_excel("df.xlsx")
print(df)
df2 = pd.read_excel("df.xlsx",1)
print(df2)
# Out:
#    Unnamed: 0   Name  Age
# 0           0      犇   28
# 1           1     中文   34
# 2           2      龘   29
# 3           3  Ricky   42
#   Unnamed: 0  One  Two  Three
# 0          a    0    1      2
# 1          c    3    4      5
# 2          d    6    7      8

# %% [markdown]
# ## 作業讀入 df3a.csv

# %%
import  pandas as pd
import  numpy as np
df=pd.DataFrame(
    np.arange(48).reshape(6,8),
    index=['a','b','c','d','e','f'],
    columns=['s','t','u','v','w','x','y','z'])
print(df)
print()
print(df.loc["c":"f"])#c開始包含f
# Out:
#     s   t   u   v   w   x   y   z
# a   0   1   2   3   4   5   6   7
# b   8   9  10  11  12  13  14  15
# c  16  17  18  19  20  21  22  23
# d  24  25  26  27  28  29  30  31
# e  32  33  34  35  36  37  38  39
# f  40  41  42  43  44  45  46  47
#
#     s   t   u   v   w   x   y   z
# c  16  17  18  19  20  21  22  23
# d  24  25  26  27  28  29  30  31
# e  32  33  34  35  36  37  38  39
# f  40  41  42  43  44  45  46  47
